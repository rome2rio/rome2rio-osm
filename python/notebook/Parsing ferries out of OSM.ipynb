# %%
from imposm.parser import OSMParser
from pprint import pprint
from IPython.display import HTML
import osmapi
import json
import urllib
from pygeocoder import Geocoder, GeocoderError
import goslate

# %%
class OSMContext:
    def __init__(self):
        self.nodes = {}
        self.ways = {}
        self.relations = {}
        self.api = osmapi.OsmApi()
        
    def add_nodes(self, data):
        nodes = [Node(self, osmid, tags, members) for osmid, tags, members in data]
        for node in nodes:
            self.nodes[node.osmid] = node
        return nodes
        
    def add_ways(self, data):
        ways = [Way(self, osmid, tags, members) for osmid, tags, members in data]
        for way in ways:
            self.ways[way.osmid] = way
        return ways
        
    def add_relations(self, data):
        relations = [Relation(self, osmid, tags, members) for osmid, tags, members in data]
        for relation in relations:
            self.relations[relation.osmid] = relation
        return relations
    
    def get_way(self, osmid):
        if osmid in self.ways:
            return self.ways[osmid]
        
    def resolve_nodes(self, node_ids):
        missing = [osmid for osmid in node_ids if osmid not in self.nodes]
        batchsize = 200
        for i in xrange(0, len(missing), batchsize):
            batch = missing[i:i + batchsize]
            print "Requesting %d nodes from OSM.." % len(batch)
            for osmid, json in self.api.NodesGet(batch):
                self.nodes[osmid] = Node(self, osmid, json['tag'], [json['lon'], json['lat']])
        
    def get_node(self, osmid):
        if osmid not in self.nodes:
            # look up the node online
            print "Looking up node %d.." % osmid
            json = self.api.NodeGet(osmid)
            if json is None:
                # we can't do anything in this situation
                return
            self.nodes[osmid] = Node(self, osmid, json['tag'], [json['lon'], json['lat']])
        return self.nodes[osmid]
        
    def get_relation(self, osmid):
        if osmid in self.relations:
            return self.relations[osmid]

class OSMObject:
    def __init__(self, context, osmid, tags, members):
        self.context = context
        self.osmid = osmid
        self.tags = tags
        self.members = members
        
class Position:
    def __init__(self, lat, lng):
        self.lat = lat
        self.lng = lng
        
    def __str__(self):
        return "(lat: %s, lng: %s)" % (self.lat, self.lng)
        
class Node(OSMObject):
    @property
    def position(self):
        return Position(self.members[1], self.members[0])
    
    def __str__(self):
        return "Node%s" % str(self.position)
    
    def __repr__(self):
        return str(self)
        
class Relation(OSMObject):
    @property
    def url(self):
        return "http://www.openstreetmap.org/relation/%s" % self.osmid
    
    def all_node_ids(self):
        return [osmid for osmid, osmtype, _ in self.members if osmtype.lower() == "node"]
    
    def get_ways(self):
        return filter(lambda x: x is not None, [self.context.get_way(osmid) for osmid, osmtype, _ in self.members if osmtype.lower() == "way"])
    
    def get_nodes(self):
        return filter(lambda x: x is not None, [self.context.get_node(osmid) for osmid in self.all_node_ids()])
    
    @property
    def start_point(self):
        ways = self.get_ways()
        if len(ways) > 0:
            return ways[0].start_point
        for osmid in self.all_node_ids():
            node = self.context.get_node(osmid)
            if node is not None:
                return node
    
    @property
    def end_point(self):
        ways = self.get_ways()
        if len(ways) > 0:
            return ways[-1].end_point
        for osmid in reversed(self.all_node_ids()):
            node = self.context.get_node(osmid)
            if node is not None:
                return node
        
    @property
    def points(self):
        all_points = self.get_nodes()
        for way in self.get_ways():
            all_points.extend(way.points)
        return filter(lambda x: x is not None, all_points)

class Way(OSMObject):
    @property
    def url(self):
        return "http://www.openstreetmap.org/way/%s" % self.osmid
    
    def all_node_ids(self):
        return self.members
    
    def get_nodes(self):
        return filter(lambda x: x is not None, [self.context.get_node(osmid) for osmid in self.all_node_ids()])
    
    @property
    def start_point(self):
        for osmid in self.all_node_ids():
            node = self.context.get_node(osmid)
            if node is not None:
                return node
    
    @property
    def end_point(self):
        for osmid in reversed(self.all_node_ids()):
            node = self.context.get_node(osmid)
            if node is not None:
                return node
    
    @property
    def points(self):
        return self.get_nodes()

class FerryRoute:
    def __init__(self, osmobj):
        self.osmobj = osmobj
        
    @property
    def url(self):
        if 'website' in self.osmobj.tags:
            #assert 'url' not in self.tags, "url:%s, website:%s" % (self.tags['url'], self.tags['website'])
            return self.osmobj.tags['website']
        if 'url' in self.osmobj.tags:
            #assert 'website' not in self.tags
            return self.osmobj.tags['url']
        for key, value in self.osmobj.tags.iteritems():
            if "http" in value.lower():
                return value
        return None
    
    @property
    def name(self):
        if 'name' in self.osmobj.tags:
            return self.osmobj.tags['name']
        if 'name:en' in self.osmobj.tags:
            return self.osmobj.tags['name:en']
        if 'name:int' in self.osmobj.tags:
            return self.osmobj.tags['name:int']
        for key in self.osmobj.tags.keys():
            if 'name' in key:
                return self.osmobj.tags[key]
        if 'ref' in self.osmobj.tags:
            return self.osmobj.tags['ref']
        return None
    
class Operator:
    def __init__(self, name):
        self.name = name
        
context = OSMContext()
operator_map = {}
ferries = []

def relations(objects):
    if objects:
        make_ferry(context.add_relations(objects))

def ways(objects):
    if objects:
        make_ferry(context.add_ways(objects))
        
def nodes(objects):
    if objects:
        context.add_nodes(objects)

def make_ferry(objects):
    for osmobj in objects:
        if 'operator' in osmobj.tags:
            if osmobj.tags['operator'] not in operator_map:
                operator_map[osmobj.tags['operator']] = Operator(osmobj.tags['operator'])
            operator = operator_map[osmobj.tags['operator']]
        else:
            if 'no operator' not in operator_map:
                operator_map['no operator'] = Operator('no operator')
            operator = operator_map['no operator']
        ferries.append(FerryRoute(osmobj))

# %%
def ferries_html(title, ferries):
    s = "<h2>%s</h2>" % title
    s += "<ul>"
    for route in ferries:
        s += "<li><a href='%s'>" % route.osmobj.url
        if route.name is None:
            s += "(unnamed ferry)"
        else:
            if route.url is not None:
                url = "(<a href='%s'>website</a>)" % route.url
            else:
                url = ""
            s += "<b>%s</b> %s" % (route.name, url)
        s += "</a></li>"
    s += "</ul>"
    return s

# %%
def get_country(positions):
    url = "http://localhost:15555/api/1.2/json/ReverseGeocode?key=oaSfxu2D&lat=%s&lng=%s"
    for pos in positions:
        query = url % (pos.lat, pos.lng)
        try:
            data = json.loads(urllib.urlopen(query).read())
            first_place = data['places'][0]
            if 'countryCode' in first_place and first_place['countryCode'] != "":
                return first_place['countryCode']
        except:
            print "error executing query: %s" % query
            raise

# %%
parser = OSMParser(relations_callback=relations, ways_callback=ways, nodes_callback=nodes, concurrency=4)
#ways_callback=ways
parser.parse(r"/home/mgi/raw/ferries.pbf")

#operators = [value for _, value in sorted(operator_map.iteritems(), key=lambda (k, v): k)]

# %%
all_node_ids = [osmid for ferry in ferries for osmid in ferry.osmobj.all_node_ids()]
context.resolve_nodes(all_node_ids)
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-90-0dc1cce08d26> in <module>()
#       1 all_node_ids = [osmid for ferry in ferries for osmid in ferry.osmobj.all_node_ids()]
# ----> 2 context.resolve_nodes(all_node_ids)
#
# <ipython-input-86-6e95507ebdc7> in resolve_nodes(self, node_ids)
#      34             batch = missing[i:i + batchsize]
#      35             print "Requesting %d nodes from OSM.." % len(batch)
# ---> 36             for osmid, json in self.api.NodesGet(batch):
#      37                 self.nodes[osmid] = Node(self, osmid, json['tag'], [json['lon'], json['lat']])
#      38
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in NodesGet(self, NodeIdList)
#     482         """
#     483         uri = "/api/0.6/nodes?nodes=" + ",".join([str(x) for x in NodeIdList])
# --> 484         data = self._get(uri)
#     485         data = xml.dom.minidom.parseString(data)
#     486         result = {}
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in _get(self, path)
#    1780
#    1781     def _get(self, path):
# -> 1782         return self._http('GET', path, False, None)
#    1783
#    1784     def _put(self, path, data):
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in _http(self, cmd, path, auth, send)
#    1756             i += 1
#    1757             try:
# -> 1758                 return self._http_request(cmd, path, auth, send)
#    1759             except ApiError as e:
#    1760                 if e.status >= 500:
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in _http_request(self, cmd, path, auth, send)
#    1742             if response.status == 410:
#    1743                 return None
# -> 1744             raise ApiError(response.status, response.reason, payload)
#    1745         if self._debug:
#    1746             error_msg = (
#
# ApiError: Request failed: 404 - Not Found -
# Requesting 200 nodes from OSM..

# %%
# WARNING! this is slow the first time, as osmfilter is filtering out many of the nodes (I have to look them up manually)
# see: https://help.openstreetmap.org/questions/41897/osmfilter-misses-dependent-nodes

ferry_by_country = {}
for i, ferry in enumerate(ferries):
    if i % 1000 == 0:
        print "Resolving ferry %d/%d" % (i + 1, len(ferries))
    points = filter(lambda x: x is not None, [ferry.osmobj.start_point, ferry.osmobj.end_point])
    
    if not points:
        print "No points associated with ferry: %s" % ferry.osmobj.url
    else:
        country = get_country(x.position for x in points)
        if country is None:
            print "No country found:", ferry.name, "URL:", ferry.osmobj.url, "Points attempted:", points
        else:
            if country not in ferry_by_country:
                ferry_by_country[country] = []
            ferry_by_country[country].append(ferry)
# Out:
# Resolving ferry 1/12389
# Looking up node 262518373..
# No points associated with ferry: http://www.openstreetmap.org/relation/305509
# No points associated with ferry: http://www.openstreetmap.org/relation/404473
# No points associated with ferry: http://www.openstreetmap.org/relation/451606
# No points associated with ferry: http://www.openstreetmap.org/relation/452743
# No points associated with ferry: http://www.openstreetmap.org/relation/931812
# No points associated with ferry: http://www.openstreetmap.org/relation/945839
# No points associated with ferry: http://www.openstreetmap.org/relation/945843
# No points associated with ferry: http://www.openstreetmap.org/relation/1131945
# No points associated with ferry: http://www.openstreetmap.org/relation/1182984
# No points associated with ferry: http://www.openstreetmap.org/relation/1182990
# Looking up node 1651608939..
# Looking up node 1651608935..
# No points associated with ferry: http://www.openstreetmap.org/relation/1629592
# Looking up node 290907612..
# Looking up node 290907612..
# No points associated with ferry: http://www.openstreetmap.org/relation/2071757
# No points associated with ferry: http://www.openstreetmap.org/relation/2745730
# No points associated with ferry: http://www.openstreetmap.org/relation/2852372
# No points associated with ferry: http://www.openstreetmap.org/relation/2852373
# No points associated with ferry: http://www.openstreetmap.org/relation/3088460
# No points associated with ferry: http://www.openstreetmap.org/relation/3088955
# No points associated with ferry: http://www.openstreetmap.org/relation/3113499
# No points associated with ferry: http://www.openstreetmap.org/relation/3451716
# No points associated with ferry: http://www.openstreetmap.org/relation/3451836
# No points associated with ferry: http://www.openstreetmap.org/relation/3453521
# Resolving ferry 1001/12389
# Looking up node 251043021..
# Resolving ferry 2001/12389
# Looking up node 427686448..
# Resolving ferry 3001/12389
# Looking up node 541637836..
# Looking up node 1612094727..
# Looking up node 632646609..
# Looking up node 632646614..
# Looking up node 632646612..
# Looking up node 681322422..
# Looking up node 681322495..
# Looking up node 681322496..
# Looking up node 681322499..
# Looking up node 681322498..
# Looking up node 681322412..
# Looking up node 681322414..
# Looking up node 681322415..
# Looking up node 681322416..
# Looking up node 681322417..
# Looking up node 681322418..
# Looking up node 681322419..
# Looking up node 681322424..
# Looking up node 681322420..
# Looking up node 681322425..
# Looking up node 681322423..
# Looking up node 681322422..
# Looking up node 681322422..
# Looking up node 681322423..
# Looking up node 681322425..
# Looking up node 681322420..
# Looking up node 681322424..
# Looking up node 681322419..
# Looking up node 681322418..
# Looking up node 681322417..
# Looking up node 681322416..
# Looking up node 681322415..
# Looking up node 681322414..
# Looking up node 681322412..
# Looking up node 681322498..
# Looking up node 681322499..
# Looking up node 681322496..
# Looking up node 681322495..
# Looking up node 681322422..
# No points associated with ferry: http://www.openstreetmap.org/way/54039348
# Looking up node 681322402..
# Looking up node 681322403..
# Looking up node 681322405..
# Looking up node 681322453..
# Looking up node 681322454..
# Looking up node 681322455..
# Looking up node 681322456..
# Looking up node 681322457..
# Looking up node 681322458..
# Looking up node 681322459..
# Looking up node 681322460..
# Looking up node 681322461..
# Looking up node 681322463..
# Looking up node 681322464..
# Looking up node 681322465..
# Looking up node 681322466..
# Looking up node 681322467..
# Looking up node 681322468..
# Looking up node 681322469..
# Looking up node 681322470..
# Looking up node 681322471..
# Looking up node 681322472..
# Looking up node 681322473..
# Looking up node 681322474..
# Looking up node 681322475..
# Looking up node 681322476..
# Looking up node 681322477..
# Looking up node 681322444..
# Looking up node 681322445..
# Looking up node 681322446..
# Looking up node 681322447..
# Looking up node 681322448..
# Looking up node 681322426..
# Looking up node 681322427..
# Looking up node 681322449..
# Looking up node 681322450..
# Looking up node 681322451..
# Looking up node 681322452..
# Looking up node 681322402..
# Looking up node 681322431..
# Resolving ferry 4001/12389
# Looking up node 667991947..
# Looking up node 910461989..
# Looking up node 910461991..
# Looking up node 1651608935..
# Resolving ferry 5001/12389
# Looking up node 1235708473..
# Resolving ferry 6001/12389
# No country found: Ялта - Новороссийск URL: http://www.openstreetmap.org/way/131893830 Points attempted: [Node(lat: 44.501178, lng: 34.6461974), Node(lat: 44.5608661, lng: 36.4164207)]
# Looking up node 290907612..
# Looking up node 1552076202..
# Looking up node 1612094727..
# Looking up node 632646615..
# Looking up node 632646617..
# Looking up node 632646622..
# Looking up node 1651608939..
# Looking up node 1651608935..
# Looking up node 1651608935..
# Looking up node 1651608939..
# No points associated with ferry: http://www.openstreetmap.org/way/152337947
# Looking up node 1742193688..
# Resolving ferry 7001/12389
# Looking up node 1864475354..
# No country found: None URL: http://www.openstreetmap.org/way/179615843 Points attempted: [Node(lat: 42.6519183, lng: 6.8550714), Node(lat: 42.6695864, lng: 6.5412001)]
# Resolving ferry 8001/12389
# Looking up node 2063626022..
# Looking up node 2063626022..
# Looking up node 2063626022..
# Looking up node 2142272133..
# Looking up node 2440613525..
# Looking up node 2440613676..
# Looking up node 2440613507..
# Looking up node 2440613476..
# Looking up node 2440613473..
# Looking up node 2440613633..
# Looking up node 2440613488..
# Looking up node 2440613559..
# Looking up node 2440613487..
# Looking up node 2440613475..
# Looking up node 2440613493..
# Looking up node 2440613625..
# Looking up node 2440613495..
# Looking up node 2440613471..
# Looking up node 2440613667..
# Looking up node 2440613608..
# Looking up node 2440613620..
# Looking up node 2440613511..
# Looking up node 2440613565..
# Looking up node 2440613666..
# Looking up node 2440613556..
# Looking up node 2440613642..
# Looking up node 2440613548..
# Looking up node 2440613546..
# Looking up node 2440613538..
# Looking up node 2440613569..
# Looking up node 2440613564..
# Looking up node 2440613583..
# Looking up node 2440613554..
# Looking up node 2440613646..
# Looking up node 2440613655..
# Looking up node 2440613492..
# Looking up node 2440613543..
# Looking up node 2440613673..
# Looking up node 2440613450..
# Looking up node 2440613634..
# Looking up node 2440613623..
# Looking up node 2440613525..
# Looking up node 2440613584..
# Looking up node 2440613631..
# Looking up node 2440613639..
# Looking up node 2440613474..
# Looking up node 2440613590..
# Looking up node 2440613503..
# Looking up node 2440613658..
# Looking up node 2440613517..
# Looking up node 2440613681..
# Looking up node 2440613644..
# Looking up node 2440613588..
# Looking up node 2440613609..
# Looking up node 2440613527..
# Looking up node 2440613641..
# Looking up node 2440613519..
# Looking up node 2440613521..
# Looking up node 2269261897..
# Looking up node 2269261892..
# Looking up node 2269261868..
# Looking up node 2269261918..
# Looking up node 2268221852..
# Looking up node 2268221850..
# Looking up node 2268221856..
# Looking up node 2268221854..
# Looking up node 2268221848..
# Looking up node 2142282440..
# Looking up node 2142282452..
# Looking up node 2268221836..
# Looking up node 2268221837..
# Looking up node 2440613463..
# Looking up node 3045088628..
# Looking up node 3045088628..
# Looking up node 2440613463..
# Looking up node 2268221837..
# Looking up node 2268221836..
# No points associated with ferry: http://www.openstreetmap.org/way/217541816
# Looking up node 2268221852..
# Looking up node 2268221841..
# Looking up node 2268221836..
# Looking up node 2268221835..
# Looking up node 2268221835..
# Looking up node 2268221836..
# Looking up node 2268221841..
# Looking up node 2268221852..
# No points associated with ferry: http://www.openstreetmap.org/way/217625478
# Resolving ferry 9001/12389
# No country found: Saint-Petersburg - Helsinki URL: http://www.openstreetmap.org/way/231467592 Points attempted: [Node(lat: 59.9067413, lng: 25.4249379), Node(lat: 59.931149, lng: 26.2533077)]
# Looking up node 2430268906..
# Looking up node 2430268907..
# Looking up node 2430268908..
# Looking up node 2430268906..
# Looking up node 2430268909..
# Looking up node 2440489925..
# Looking up node 2440489923..
# Looking up node 2440489924..
# Looking up node 2440489924..
# Looking up node 2440489923..
# No points associated with ferry: http://www.openstreetmap.org/way/235974282
# Looking up node 2440489929..
# Looking up node 2440489923..
# Looking up node 2440489920..
# Looking up node 2440489918..
# Looking up node 2440489919..
# Looking up node 2440489921..
# Looking up node 2440489921..
# Looking up node 2440489919..
# Looking up node 2440489918..
# Looking up node 2440489920..
# Looking up node 2440489923..
# Looking up node 2440489929..
# No points associated with ferry: http://www.openstreetmap.org/way/235974283
# Looking up node 2440489921..
# Looking up node 2440489922..
# Looking up node 2440489922..
# Looking up node 2440489921..
# No points associated with ferry: http://www.openstreetmap.org/way/235974284
# Looking up node 2440489920..
# Looking up node 2440489927..
# Looking up node 2440489927..
# Looking up node 2440489920..
# No points associated with ferry: http://www.openstreetmap.org/way/235974285
# Looking up node 2440489919..
# Looking up node 2440489928..
# Looking up node 2440489928..
# Looking up node 2440489919..
# No points associated with ferry: http://www.openstreetmap.org/way/235974287
# Looking up node 2440489918..
# Looking up node 2440489926..
# Looking up node 2440489926..
# Looking up node 2440489918..
# No points associated with ferry: http://www.openstreetmap.org/way/235974288
# Looking up node 2440613644..
# Looking up node 2440613641..
# Looking up node 2440613641..
# Looking up node 2440613644..
# No points associated with ferry: http://www.openstreetmap.org/way/235986571
# Looking up node 2440613515..
# Looking up node 2440613623..
# Looking up node 2440613623..
# Looking up node 2440613515..
# No points associated with ferry: http://www.openstreetmap.org/way/235986572
# Looking up node 2440613574..
# Looking up node 2440613578..
# Looking up node 2440613578..
# Looking up node 2440613574..
# No points associated with ferry: http://www.openstreetmap.org/way/235986573
# Looking up node 2440613609..
# Looking up node 2440613606..
# Looking up node 2440613606..
# Looking up node 2440613609..
# No points associated with ferry: http://www.openstreetmap.org/way/235986574
# Looking up node 2440613588..
# Looking up node 2440613452..
# Looking up node 2440613452..
# Looking up node 2440613588..
# No points associated with ferry: http://www.openstreetmap.org/way/235986575
# Looking up node 2440613580..
# Looking up node 2440613679..
# Looking up node 2440613675..
# Looking up node 2440613617..
# Looking up node 2440613532..
# Looking up node 2440613456..
# Looking up node 2440613600..
# Looking up node 2440613458..
# Looking up node 2440613677..
# Looking up node 2440613678..
# Looking up node 2440613686..
# Looking up node 2440613535..
# Looking up node 2440613486..
# Looking up node 2440613592..
# Looking up node 2440613468..
# Looking up node 2440613680..
# Looking up node 2440613637..
# Looking up node 2440613630..
# Looking up node 2440613596..
# Looking up node 2440613557..
# Looking up node 2440613579..
# Looking up node 2440613470..
# Looking up node 2440613640..
# Looking up node 2440613460..
# Looking up node 2440613459..
# Looking up node 2440613483..
# Looking up node 2440613654..
# Looking up node 2440613562..
# Looking up node 2440613454..
# Looking up node 2440613462..
# Looking up node 2440613684..
# Looking up node 2440613624..
# Looking up node 2440613541..
# Looking up node 2440613530..
# Looking up node 2440613465..
# Looking up node 2440613605..
# Looking up node 2440613518..
# Looking up node 2440613611..
# Looking up node 2440613614..
# Looking up node 2440613461..
# Looking up node 2440613497..
# Looking up node 2440613500..
# Looking up node 2440613499..
# Looking up node 2440613651..
# Looking up node 2440613561..
# Looking up node 2440613561..
# Looking up node 2440613651..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-65d8b4b90002> in <module>()
#       6     if i % 1000 == 0:
#       7         print "Resolving ferry %d/%d" % (i + 1, len(ferries))
# ----> 8     points = filter(lambda x: x is not None, [ferry.osmobj.start_point, ferry.osmobj.end_point])
#       9
#      10     if not points:
#
# <ipython-input-10-186702e7aa39> in end_point(self)
#     128     def end_point(self):
#     129         for osmid in reversed(self.members):
# --> 130             node = self.context.get_node(osmid)
#     131             if node is not None:
#     132                 return node
#
# <ipython-input-10-186702e7aa39> in get_node(self, osmid)
#      32             # look up the node online
#      33             print "Looking up node %d.." % osmid
# ---> 34             json = self.api.NodeGet(osmid)
#      35             if json is None:
#      36                 # we can't do anything in this situation
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in NodeGet(self, NodeId, NodeVersion)
#     272         if NodeVersion != -1:
#     273             uri += "/"+str(NodeVersion)
# --> 274         data = self._get(uri)
#     275         if not data:
#     276             return data
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in _get(self, path)
#    1780
#    1781     def _get(self, path):
# -> 1782         return self._http('GET', path, False, None)
#    1783
#    1784     def _put(self, path, data):
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in _http(self, cmd, path, auth, send)
#    1756             i += 1
#    1757             try:
# -> 1758                 return self._http_request(cmd, path, auth, send)
#    1759             except ApiError as e:
#    1760                 if e.status >= 500:
#
# /usr/local/lib/python2.7/dist-packages/osmapi/OsmApi.pyc in _http_request(self, cmd, path, auth, send)
#    1737         if send:
#    1738             self._conn.send(send)
# -> 1739         response = self._conn.getresponse()
#    1740         if response.status != 200:
#    1741             payload = response.read().strip()
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1043         response = self.response_class(*args, **kwds)
#    1044
# -> 1045         response.begin()
#    1046         assert response.will_close != _UNKNOWN
#    1047         self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     407         # read until we get a non-100 response
#     408         while True:
# --> 409             version, status, reason = self._read_status()
#     410             if status != CONTINUE:
#     411                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     363     def _read_status(self):
#     364         # Initialize with Simple-Response defaults
# --> 365         line = self.fp.readline(_MAXLINE + 1)
#     366         if len(line) > _MAXLINE:
#     367             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
code = 'JP'

gs = goslate.Goslate()
s = unicode("<h1>Ferries in %s</h1>" % code)
for ferry in ferry_by_country[code]:
    url = ferry.url
    if ferry.name is None:
        name = "<small><b>unknown</b></small>"
    else:
        name = gs.translate(ferry.name, "en")
    if url is None:
        s += name
    else:
        s += "<a href='%s'>%s</a>" % (url, name)
    s += " <small>(<a href='%s'>view on osm</a>)</small><br/>" % ferry.osmobj.url
HTML(s)
# Out:
# <h1>Ferries in JP</h1>Donghae - Sakaiminato <small>(<a href='http://www.openstreetmap.org/relation/1144862'>view on osm</a>)</small><br/>Tonosho - Takamatsu route <small>(<a href='http://www.openstreetmap.org/relation/2491148'>view on osm</a>)</small><br/>Ikeda - Takamatsu route <small>(<a href='http://www.openstreetmap.org/relation/2491150'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/relation/2671699'>view on osm</a>)</small><br/>Oshima ferry route Okada Port Direct flight <small>(<a href='http://www.openstreetmap.org/relation/2718910'>view on osm</a>)</small><br/>Triton line <small>(<a href='http://www.openstreetmap.org/relation/3377419'>view on osm</a>)</small><br/>Tomakomai West Port Ferry Terminal <small>(<a href='http://www.openstreetmap.org/relation/3898628'>view on osm</a>)</small><br/>Chivas seabass <small>(<a href='http://www.openstreetmap.org/way/27734340'>view on osm</a>)</small><br/>Chivas seabass <small>(<a href='http://www.openstreetmap.org/way/27734358'>view on osm</a>)</small><br/>Ise Bay Ferry <small>(<a href='http://www.openstreetmap.org/way/30263603'>view on osm</a>)</small><br/>Meitetsu Ferry <small>(<a href='http://www.openstreetmap.org/way/30263604'>view on osm</a>)</small><br/>Shodoshima express ferry <small>(<a href='http://www.openstreetmap.org/way/31905876'>view on osm</a>)</small><br/>Hakone Sightseeing Cruise <small>(<a href='http://www.openstreetmap.org/way/34123396'>view on osm</a>)</small><br/>Hakone Sightseeing Cruise <small>(<a href='http://www.openstreetmap.org/way/34123586'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/way/34575280'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/way/34575438'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/way/34597465'>view on osm</a>)</small><br/>Hakone Sightseeing Cruise <small>(<a href='http://www.openstreetmap.org/way/34604527'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/way/34765121'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/way/34916201'>view on osm</a>)</small><br/>Chitose passed <small>(<a href='http://www.openstreetmap.org/way/34943252'>view on osm</a>)</small><br/>Jinbei crossing <small>(<a href='http://www.openstreetmap.org/way/34945115'>view on osm</a>)</small><br/>Kumamoto - Shimabara <small>(<a href='http://www.openstreetmap.org/way/35565353'>view on osm</a>)</small><br/>Sado Kisen Niigata - Ryotsu <small>(<a href='http://www.openstreetmap.org/way/38620645'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/way/39101159'>view on osm</a>)</small><br/>Venus; ferry district <small>(<a href='http://www.openstreetmap.org/way/41424480'>view on osm</a>)</small><br/>World heritage route <small>(<a href='http://www.openstreetmap.org/way/41666405'>view on osm</a>)</small><br/><small><b>unknown</b></small> <small>(<a href='http://www.openstreetmap.org/way/41668797'>view on osm</a>)</small><br/>JR Miyajima contact line <small>(<a href='http://www.openstreetmap.org/way/41961998'>view on osm</a>)</small><br/>JR Miyajima contact line <small>(<a href='http://www.openstreetmap.org/way/41963252'>view on osm</a>)</small><br/>Donghae - Sakaiminato <small>(<a href='http://www.openstreetmap.org/way/42256885'>view on osm</a>)</small><br/>Nankai Ferry <small>(<a href='http://www.openstreetmap.org/way/42975873'>view on osm</a>)</small><br/>Imabari Municipal Sekizen ferry (Imabari - large under-Kooge Okamura) <small>(<a href='http://www.openstreetmap.org/way/43007717'>view on osm</a>)</small><br/>Imabari Municipal Sekizen ferry (Imabari - large under-Kooge Okamura) <small>(<a href='http://www.openstreetmap.org/way/43007718'>view on osm</a>)</small><br/>Imabari Mun ...

# %%
import pycountry
total = 0
for country, ferry_lines in ferry_by_country.iteritems():
    print "%s: %d ferry lines" % (pycountry.countries.get(alpha2=country).name, len(ferry_lines))
    total += len(ferry_lines)
print "TOTAL: %d" % total
# Out:
# Bangladesh: 3 ferry lines
# Belgium: 16 ferry lines
# Bulgaria: 1 ferry lines
# Bermuda: 3 ferry lines
# Brunei Darussalam: 1 ferry lines
# Bolivia, Plurinational State of: 1 ferry lines
# Japan: 23 ferry lines
# Botswana: 1 ferry lines
# Brazil: 34 ferry lines
# Bahamas: 2 ferry lines
# Russian Federation: 81 ferry lines
# Rwanda: 2 ferry lines
# Romania: 6 ferry lines
# Guatemala: 4 ferry lines
# Greece: 87 ferry lines
# Guyana: 7 ferry lines
# Guernsey: 3 ferry lines
# Georgia: 5 ferry lines
# Grenada: 1 ferry lines
# United Kingdom: 162 ferry lines
# Gambia: 3 ferry lines
# Greenland: 1 ferry lines
# Ghana: 3 ferry lines
# Tunisia: 2 ferry lines
# Croatia: 35 ferry lines
# Hungary: 24 ferry lines
# Costa Rica: 1 ferry lines
# Portugal: 8 ferry lines
# Paraguay: 1 ferry lines
# Panama: 5 ferry lines
# Philippines: 54 ferry lines
# Poland: 40 ferry lines
# Estonia: 3 ferry lines
# Egypt: 4 ferry lines
# South Africa: 2 ferry lines
# Ecuador: 1 ferry lines
# Albania: 1 ferry lines
# Spain: 48 ferry lines
# Montenegro: 1 ferry lines
# Moldova, Republic of: 1 ferry lines
# Madagascar: 3 ferry lines
# Morocco: 2 ferry lines
# Monaco: 1 ferry lines
# Mali: 3 ferry lines
# Mongolia: 1 ferry lines
# United States: 175 ferry lines
# Malta: 2 ferry lines
# Maldives: 1 ferry lines
# Isle of Man: 2 ferry lines
# Malaysia: 4 ferry lines
# Mexico: 1 ferry lines
# France: 112 ferry lines
# Finland: 77 ferry lines
# Faroe Islands: 2 ferry lines
# Nicaragua: 6 ferry lines
# Netherlands: 174 ferry lines
# Norway: 176 ferry lines
# New Zealand: 31 ferry lines
# Cook Islands: 1 ferry lines
# Côte d'Ivoire: 1 ferry lines
# Switzerland: 116 ferry lines
# Colombia: 6 ferry lines
# China: 52 ferry lines
# Chile: 15 ferry lines
# Canada: 67 ferry lines
# Congo, The Democratic Republic of the: 4 ferry lines
# Czech Republic: 15 ferry lines
# Uruguay: 3 ferry lines
# Cape Verde: 9 ferry lines
# Syrian Arab Republic: 1 ferry lines
# Kenya: 5 ferry lines
# Suriname: 2 ferry lines
# Cambodia: 4 ferry lines
# Slovakia: 4 ferry lines
# Korea, Republic of: 5 ferry lines
# Slovenia: 1 ferry lines
# Senegal: 5 ferry lines
# Sierra Leone: 1 ferry lines
# Singapore: 1 ferry lines
# Sweden: 115 ferry lines
# Denmark: 60 ferry lines
# Germany: 526 ferry lines
# Algeria: 8 ferry lines
# Tanzania, United Republic of: 4 ferry lines
# Lao People's Democratic Republic: 11 ferry lines
# Turkey: 56 ferry lines
# Sri Lanka: 1 ferry lines
# Latvia: 5 ferry lines
# Lithuania: 8 ferry lines
# Thailand: 20 ferry lines
# United Arab Emirates: 2 ferry lines
# Antigua and Barbuda: 1 ferry lines
# Iceland: 3 ferry lines
# Iran, Islamic Republic of: 1 ferry lines
# Italy: 108 ferry lines
# Viet Nam: 1 ferry lines
# Argentina: 9 ferry lines
# Australia: 74 ferry lines
# Austria: 24 ferry lines
# India: 11 ferry lines
# Azerbaijan: 2 ferry lines
# Ireland: 13 ferry lines
# Indonesia: 7 ferry lines
# Ukraine: 19 ferry lines
# TOTAL: 2861
